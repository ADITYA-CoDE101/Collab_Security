# %%
from pathlib import Path


path = Path('users.txt')
read_files = path
print(read_files) # list of files successfully read
if not read_files:
    # handle missing config file (use defaults, log, or raise)
    pass
# Out:
# users.txt

# %%
from time import sleep
from subprocess import run

def loading(flag = 0):
    for i in range(4):
        print(".", end="")
        sleep(0.5)
    if flag == 0:
        print(".")

print("Connecting to the server",end=" ")
loading(1)

print("helllo")
# Out:
# Connecting to the server ....helllo

# %%
import subprocess

# Example 1: Running a simple command and printing its output
try:
    result = subprocess.run(['ls', '-l'], capture_output=True, text=True, check=True)
    print("Command output:")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print(f"Error executing command: {e}")
    print(f"Stderr: {e.stderr}")

# Example 2: Running a command with arguments and redirecting output to a file
try:
    with open('output.txt', 'w') as f:
        subprocess.run(['echo', 'Hello from Python!'], stdout=f, check=True)
    print("Output written to output.txt")
except subprocess.CalledProcessError as e:
    print(f"Error executing command: {e}")

# %%
if None:
    print('fgf')
else:
    print('dffd')
# Out:
# dffd

# %%
def test():
    return True

if not test():
    print("hdh")

# %%
import os 
file_path = os.path.abspath("Config/server.confg")
if os.path.isfile(file_path):
    print(f"The file '{file_path}' exists and is a file.")
else:
    print(f"The file '{file_path}' does not exist or is not a file.")

file_path1 = os.path.join("my_directory", "my_file.txt")
print(file_path1)
# Out:
# The file '/home/dell/Documents/Coding/git_test/backup_files/TCP-communication-/test/ snippet_testing/Config/server.confg' does not exist or is not a file.
# my_directory/my_file.txt

# %%
c = """# Chat server configuration
# Save as /home/dell/Documents/Coding/git_test/backup_files/TCP-communication-/Servers/chat.confg

[server]
# Address and port to listen on
bind_address = 0.0.0.0
port = 12345
protocol = tcp

[mysql]
host = localhost
user = dell
password = 1234 
database = chat1

# Text shown to clients after connect
welcome_message = Welcome to the Chat Server!
motd = Be respectful. No spam.

# Maximum simultaneous connected clients
max_clients = 100

[logging]
level = info       # debug, info, warn, error
file = /var/log/chat_server.log
rotate = daily
max_size_mb = 50

[security]
enable_tls = false
tls_cert = /etc/ssl/certs/chat_server.crt
tls_key = /etc/ssl/private/chat_server.key

# Authentication options
require_auth = false
auth_method = password  # password, token, oauth
# If require_auth = true, provide a user store or hook in your server implementation

# IP/CIDR entries allowed to connect (comma separated), use * for all
allowed_clients = *

[limits]
max_message_length = 2048
max_join_rate_per_minute = 60   # connections per minute from same IP
connection_timeout_seconds = 300
heartbeat_interval_seconds = 60

[storage]
message_history_enabled = true
history_retention_days = 30
storage_path = /var/lib/chat_server/messages.db

[users]
# Example admin entry (store real hashed passwords in production)
admin_user = admin
admin_pass_hash = 

# End of configuration"""
print(c)
with open("f.txt", "w") as f:
    f.writelines(c)
# Out:
# # Chat server configuration
# # Save as /home/dell/Documents/Coding/git_test/backup_files/TCP-communication-/Servers/chat.confg
#
# [server]
# # Address and port to listen on
# bind_address = 0.0.0.0
# port = 12345
# protocol = tcp
#
# [mysql]
# host = localhost
# user = dell
# password = 1234
# database = chat1
#
# # Text shown to clients after connect
# welcome_message = Welcome to the Chat Server!
# motd = Be respectful. No spam.
#
# # Maximum simultaneous connected clients
# max_clients = 100
#
# [logging]
# level = info       # debug, info, warn, error
# file = /var/log/chat_server.log
# rotate = daily
# max_size_mb = 50
#
# [security]
# enable_tls = false
# tls_cert = /etc/ssl/certs/chat_server.crt
# tls_key = /etc/ssl/private/chat_server.key
#
# # Authentication options
# require_auth = false
# auth_method = password  # password, token, oauth
# # If require_auth = true, provide a user store or hook in your server implementation
#
# # IP/CIDR entries allowed to connect (comma separated), use * for all
# allowed_clients = *
#
# [limits]
# max_message_length = 2048
# max_join_rate_per_minute = 60   # connections per minute from same IP
# connection_timeout_seconds = 300
# heartbeat_interval_seconds = 60
#
# [storage]
# message_history_enabled = true
# history_retention_days = 30
# storage_path = /var/lib/chat_server/messages.db
#
# [users]
# # Example admin entry (store real hashed passwords in production)
# admin_user = admin
# admin_pass_hash =
#
# # End of configuration

# %%
def t(l :list , k:str ):
      print(l)
      print(k)

t((2,3,4),3)
# Out:
# (2, 3, 4)
# 3
